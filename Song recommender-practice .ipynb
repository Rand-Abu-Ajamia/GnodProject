# %% [markdown]
# # loading credentials & libraries

# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
#searching a specific song 
results = sp.search(q="Bily Joel",market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bily+Joel&type=track&market=GB&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#        'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#        'id': '6zFYqv1mOsgBRQbae3JJ9e',
#        'name': 'Billy Joel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3R3x4zIabsvpD3yxqLaUpc'},
#      'href': 'https://api.spotify.com/v1/albums/3R3x4zIabsvpD3yxqLaUpc',
#      'id': '3R3x4zIabsvpD3yxqLaUpc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273814cbc4746358a25c84c62e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02814cbc4746358a25c84c62e7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851814cbc4746358a25c84c62e7',
#        'width': 64}],
#      'name': 'An Innocent Man',
#      'release_date': '1983-08-08',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3R3x4zIabsvpD3yxqLaUpc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 1,
#     'duration_ms': 197706,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18300270'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5zA8vzDGqPl2AzZkEYQGKh'},
#     'href': 'https://api.spotify.com/v1/tracks/5zA8vzDGqPl2AzZkEYQGKh',
#     'id': '5zA8vzDGqPl2AzZkEYQGKh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Uptown Girl',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4b8af3105f507737b8634eebecc486516274afd3?cid=a944a9d628d64afb8064ac3c39322e12',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5zA8vzDGqPl2AzZkEYQGKh'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#        'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#        'id': '6zFYqv1mOsgBRQbae3JJ9e',
#        'name': 'Billy Joel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Vw2uoVkLAJFVViJ1QyK1D'},
#      'href': 'https://api.spotify.com/v1/albums/1Vw2uoVkLAJFVViJ1QyK1D',
#      'id': '1Vw2uoVkLAJFVViJ1QyK1D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731946747b8692919f98918ec4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021946747b8692919f98918ec4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511946747b8692919f98918ec4',
#        'width': 64}],
#      'name': 'Storm Front',
#      'release_date': '1989-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1Vw2uoVkLAJFVViJ1QyK1D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 1,
#     'duration_ms': 287733,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18900217'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Cx4yrFaX8CeHwBMReOWXI'},
#     'href': 'https://api.spotify.com/v1/tracks/3Cx4yrFaX8CeHwBMReOWXI',
#     'id': '3Cx4yrFaX8CeHwBMReOWXI',
#     'is_local': False,
#     'is_playable': True,
#     'name': "We Didn't Start the Fire",
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/84365368ace21bc568ed0d9b0b18669a58963297?cid=a944a9d628d64afb8064ac3c39322e12',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3Cx4yrFaX8CeHwBMReOWXI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#        'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#        'id': '6zFYqv1mOsgBRQbae3JJ9e',
#        'name': 'Billy Joel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/69wjSAZXZiD2EBia3b3gxL'},
#      'href': 'https://api.spotify.com/v1/albums/69wjSAZXZiD2EBia3b3gxL',
#      'id': '69wjSAZXZiD2EBia3b3gxL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aff4aef671b2510be7c115b3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aff4aef671b2510be7c115b3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aff4aef671b2510be7c115b3',
#        'width': 64}],
#      'name': 'Piano Man (Legacy Edition)',
#      'release_date': '1973-11-07',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:69wjSAZXZiD2EBia3b3gxL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 1,
#     'duration_ms': 339000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM17300504'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/70C4NyhjD5OZUMzvWZ3njJ'},
#     'href': 'https://api.spotify.com/v1/tracks/70C4NyhjD5OZUMzvWZ3njJ',
#     'id': '70C4NyhjD5OZUMzvWZ3njJ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Piano Man',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7f1dc0e2f56c946849ac2e61dfa1ce827fb8dc70?cid=a944a9d628d64afb8064ac3c39322e12',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:70C4NyhjD5OZUMzvWZ3njJ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#        'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#        'id': '6zFYqv1mOsgBRQbae3JJ9e',
#        'name': 'Billy Joel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Mhn9VosyjtWn4dMPFlna6'},
#      'href': 'https://api.spotify.com/v1/albums/1Mhn9VosyjtWn4dMPFlna6',
#      'id': '1Mhn9VosyjtWn4dMPFlna6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736ce61113662ecf693b605ee5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026ce61113662ecf693b605ee5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516ce61113662ecf693b605ee5',
#        'width': 64}],
#      'name': 'The Stranger (Legacy Edition)',
#      'release_date': '1977',
#      'release_date_precision': 'year',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:1Mhn9VosyjtWn4dMPFlna6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 1,
#     'duration_ms': 201373,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM17700375'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RgFlk1fcClZd0Y4SGYhqH'},
#     'href': 'https://api.spotify.com/v1/tracks/5RgFlk1fcClZd0Y4SGYhqH',
#     'id': '5RgFlk1fcClZd0Y4SGYhqH',
#     'is_local': False,
#     'is_playable': True,
#     'name': "She's Always a Woman",
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/
',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273649d4f282653ab8be56f447e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02649d4f282653ab8be56f447e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851649d4f282653ab8be56f447e',
#        'width': 64}],
#      'name': 'The Essential Billy Joel',
#      'release_date': '2001-10-02',
#      'release_date_precision': 'day',
#      'total_tracks': 36,
#      'type': 'album',
#      'uri': 'spotify:album:7r36rel1M4gyBavfcJP6Yz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 2,
#     'duration_ms': 194866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18300270'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3CSpzkoL1XgDBZ1q9aDCUV'},
#     'href': 'https://api.spotify.com/v1/tracks/3CSpzkoL1XgDBZ1q9aDCUV',
#     'id': '3CSpzkoL1XgDBZ1q9aDCUV',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Uptown Girl',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d3b37bdad05ca2e573eb096fa19521b3fe36adba?cid=a944a9d628d64afb8064ac3c39322e12',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3CSpzkoL1XgDBZ1q9aDCUV'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#        'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#        'id': '6zFYqv1mOsgBRQbae3JJ9e',
#        'name': 'Billy Joel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5sztejERqpktXEdemlUvU5'},
#      'href': 'https://api.spotify.com/v1/albums/5sztejERqpktXEdemlUvU5',
#      'id': '5sztejERqpktXEdemlUvU5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27322d5199692d318c28d6c7d9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0222d5199692d318c28d6c7d9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485122d5199692d318c28d6c7d9b',
#        'width': 64}],
#      'name': 'Glass Houses',
#      'release_date': '1980-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5sztejERqpktXEdemlUvU5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 1,
#     'duration_ms': 176440,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18000211'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64UioB4Nmwgn2f4cbIpAkl'},
#     'href': 'https://api.spotify.com/v1/tracks/64UioB4Nmwgn2f4cbIpAkl',
#     'id': '64UioB4Nmwgn2f4cbIpAkl',
#     'is_local': False,
#     'is_playable': True,
#     'name': "It's Still Rock and Roll to Me",
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6093eca9ada1703e23bed495e84cb8ded9a6496f?cid=a944a9d628d64afb8064ac3c39322e12',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:64UioB4Nmwgn2f4cbIpAkl'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 10}}

# %%
#To get one song and play it here 
from IPython.display import IFrame
track_id = "4U45aEWtQhrm8A5mxPaFZ7?si=1b12840221d6403c"
IFrame(src=f"https://open.spotify.com/embed/track/{track_id}",
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/4U45aEWtQhrm8A5mxPaFZ7?si=1b12840221d6403c?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(results['tracks']['items'])
# Out:
# 10

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][2]['id']
# Out:
# '70C4NyhjD5OZUMzvWZ3njJ'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item['external_urls']['spotify']))
# Out:
# The name of song is: 'Uptown Girl' and the id is: https://open.spotify.com/track/5zA8vzDGqPl2AzZkEYQGKh
# The name of song is: 'We Didn't Start the Fire' and the id is: https://open.spotify.com/track/3Cx4yrFaX8CeHwBMReOWXI
# The name of song is: 'Piano Man' and the id is: https://open.spotify.com/track/70C4NyhjD5OZUMzvWZ3njJ
# The name of song is: 'She's Always a Woman' and the id is: https://open.spotify.com/track/5RgFlk1fcClZd0Y4SGYhqH
# The name of song is: 'Vienna' and the id is: https://open.spotify.com/track/4U45aEWtQhrm8A5mxPaFZ7
# The name of song is: 'My Life' and the id is: https://open.spotify.com/track/4ZoBC5MhSEzuknIgAkBaoT
# The name of song is: 'Just the Way You Are' and the id is: https://open.spotify.com/track/49MHCPzvMLXhRjDantBMVH
# The name of song is: 'Zanzibar' and the id is: https://open.spotify.com/track/70Znjq5VPKFrwlB7O26SWT
# The name of song is: 'Uptown Girl' and the id is: https://open.spotify.com/track/3CSpzkoL1XgDBZ1q9aDCUV
# The name of song is: 'It's Still Rock and Roll to Me' and the id is: https://open.spotify.com/track/64UioB4Nmwgn2f4cbIpAkl

# %%
results["tracks"]["items"][0]['name']
# Out:
# 'Uptown Girl'

# %%
import pandas as pd

song = sp.search(q="Uptown Girl", limit=1,market="GB") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Uptown+Girl&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#        'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#        'id': '6zFYqv1mOsgBRQbae3JJ9e',
#        'name': 'Billy Joel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3R3x4zIabsvpD3yxqLaUpc'},
#      'href': 'https://api.spotify.com/v1/albums/3R3x4zIabsvpD3yxqLaUpc',
#      'id': '3R3x4zIabsvpD3yxqLaUpc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273814cbc4746358a25c84c62e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02814cbc4746358a25c84c62e7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851814cbc4746358a25c84c62e7',
#        'width': 64}],
#      'name': 'An Innocent Man',
#      'release_date': '1983-08-08',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3R3x4zIabsvpD3yxqLaUpc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFYqv1mOsgBRQbae3JJ9e'},
#       'href': 'https://api.spotify.com/v1/artists/6zFYqv1mOsgBRQbae3JJ9e',
#       'id': '6zFYqv1mOsgBRQbae3JJ9e',
#       'name': 'Billy Joel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFYqv1mOsgBRQbae3JJ9e'}],
#     'disc_number': 1,
#     'duration_ms': 197706,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18300270'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5zA8vzDGqPl2AzZkEYQGKh'},
#     'href': 'https://api.spotify.com/v1/tracks/5zA8vzDGqPl2AzZkEYQGKh',
#     'id': '5zA8vzDGqPl2AzZkEYQGKh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Uptown Girl',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4b8af3105f507737b8634eebecc486516274afd3?cid=a944a9d628d64afb8064ac3c39322e12',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5zA8vzDGqPl2AzZkEYQGKh'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Uptown+Girl&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 1409}}

# %%
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5zA8vzDGqPl2AzZkEYQGKh'

# %%
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.701,
#  'energy': 0.944,
#  'key': 4,
#  'loudness': -2.986,
#  'mode': 1,
#  'speechiness': 0.0455,
#  'acousticness': 0.0755,
#  'instrumentalness': 0,
#  'liveness': 0.601,
#  'valence': 0.792,
#  'tempo': 128.993,
#  'type': 'audio_features',
#  'id': '5zA8vzDGqPl2AzZkEYQGKh',
#  'uri': 'spotify:track:5zA8vzDGqPl2AzZkEYQGKh',
#  'track_href': 'https://api.spotify.com/v1/tracks/5zA8vzDGqPl2AzZkEYQGKh',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zA8vzDGqPl2AzZkEYQGKh',
#  'duration_ms': 197707,
#  'time_signature': 4}

# %%
my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

print(my_dict)
my_dict_new = { key: [my_dict[key]] for key in list(my_dict.keys()) }
#my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
print(my_dict_new)

pd.DataFrame(my_dict_new)
# Out:
# {'danceability': 0.701, 'energy': 0.944, 'key': 4, 'loudness': -2.986, 'mode': 1, 'speechiness': 0.0455, 'acousticness': 0.0755, 'instrumentalness': 0, 'liveness': 0.601, 'valence': 0.792, 'tempo': 128.993, 'type': 'audio_features', 'id': '5zA8vzDGqPl2AzZkEYQGKh', 'uri': 'spotify:track:5zA8vzDGqPl2AzZkEYQGKh', 'track_href': 'https://api.spotify.com/v1/tracks/5zA8vzDGqPl2AzZkEYQGKh', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zA8vzDGqPl2AzZkEYQGKh', 'duration_ms': 197707, 'time_signature': 4}
# {'danceability': [0.701], 'energy': [0.944], 'key': [4], 'loudness': [-2.986], 'mode': [1], 'speechiness': [0.0455], 'acousticness': [0.0755], 'instrumentalness': [0], 'liveness': [0.601], 'valence': [0.792], 'tempo': [128.993], 'type': ['audio_features'], 'id': ['5zA8vzDGqPl2AzZkEYQGKh'], 'uri': ['spotify:track:5zA8vzDGqPl2AzZkEYQGKh'], 'track_href': ['https://api.spotify.com/v1/tracks/5zA8vzDGqPl2AzZkEYQGKh'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/5zA8vzDGqPl2AzZkEYQGKh'], 'duration_ms': [197707], 'time_signature': [4]}
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.701   0.944    4    -2.986     1       0.0455        0.0755
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0                 0     0.601    0.792  128.993  audio_features
#
#                        id                                   uri  \
# 0  5zA8vzDGqPl2AzZkEYQGKh  spotify:track:5zA8vzDGqPl2AzZkEYQGKh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5zA8vzDGqPl2...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5zA8...       197707
#
#    time_signature
# 0               4
